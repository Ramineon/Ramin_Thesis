# %%
import os
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 24985 - 25 = 24960  real end point
# 156 * 5 = 780    for every step   --> 156 * (n-1) which n is number of file
class RecurrencePlot:
    def __init__(self, input_address, output_address, window_size, start=0, end_point=320, color="viridis", res=1024 ):
        self.input_address = input_address
        self.output_address = output_address
        self.window_size = window_size
        self.start = start
        self.end_point = end_point
        self.chunks_dict = {}
        self.color = color
        self.res = res
        self.load_data()
        self.plotris()

    def recurrence_plot_magnitude(self,A):
        N = len(A)
        distance_matrix = np.zeros((N, N))
        for i in range(N):
            for j in range(N):
                distance_matrix[i, j] = np.abs(A[i] - A[j])
        return distance_matrix

    def load_data(self):
        chunks_dict = {}
        address = self.input_address
        pre_df = pd.read_csv(address)
        df = pre_df.iloc[15:, [1, 3, 5]].values.astype(float)
        df = df[:,0]
        for i in range(self.start, self.end_point, self.window_size):
            chunks_dict[i // self.window_size] = df[i:i + self.window_size]
        self.chunks_dict = chunks_dict
        os.makedirs(self.output_address, exist_ok=True)

    def plotris(self):
        for key, chunk in self.chunks_dict.items():
            plot = self.recurrence_plot_magnitude(chunk)
            plt.figure(figsize=(11, 11))
            plt.imshow(plot, cmap=self.color, origin='lower')
            
            # Hide axes and tick marks
            plt.axis('off')
            
            filename = f'pic_{key}.jpg'
            full_path = os.path.join(self.output_address, filename)
            
            # Save the figure without borders and padding
            plt.savefig(full_path, dpi=self.res / 11, bbox_inches='tight', pad_inches=0, format='jpg') # pad_inches=0  remove pad
            plt.close()

# %%
directory_out = r"G:\TheLis\1"
directory_in = r"F:\Thesis\Data Set\Machin_Train_URF\Machin_Train_URF\0\1420"
# 4 * 156 = 624 to 780  (for 5 file  or x files ==> (x-1)*156 = step)
RecurrencePlot(directory_in, directory_out, 160)

# %%
# 24985 - 25 = 24960  real end point
# 156 * 5 = 780    for every step   --> 156 * (n-1) which n is number of file
class RecurrencePlot:
    def __init__(self, input_address, output_address, window_size, start=0, end_point=320):
        self.input_address = input_address
        self.output_address = output_address
        self.window_size = window_size
        self.start = start
        self.end_point = end_point
        self.chunks_dict = {}
        self.load_data()
        self.plotris()

    def recurrence_plot_magnitude(self,A):    
        N = len(A)
        distance_matrix = np.zeros((N, N))
        for i in range(N):
            for j in range(N):
                distance_matrix[i, j] = np.abs(A[i] - A[j])
        return distance_matrix

    def load_data(self):
        chunks_dict = {}
        address = self.input_address
        pre_df = pd.read_csv(address)
        df = pre_df.iloc[15:, [1, 3, 5]].values.astype(float)
        df = df[:,0]
        for i in range(self.start, self.end_point, self.window_size):
            chunks_dict[i // self.window_size] = df[i:i + self.window_size]
        self.chunks_dict = chunks_dict
        os.makedirs(self.output_address, exist_ok=True)

# %%
import os
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class RecurrencePlot_v2:
    def __init__(self, input_address, output_address, iteration=0, window_size=160, start=0, end_point=24960,
                 color="rainbow",
                 res=1024):
        self.input_address = input_address
        self.output_address = output_address
        self.window_size = window_size
        self.start = start
        self.end_point = end_point
        self.chunks_dict = {}
        self.color = color
        self.res = res
        self.iteration = iteration
        self.load_data()
        self.Saveon()

    def recurrence_plot_magnitude(self, A):
        N = len(A)
        distance_matrix = np.zeros((N, N))
        for i in range(N):
            for j in range(N):
                distance_matrix[i, j] = np.abs(A[i] - A[j])
        return distance_matrix

    def load_data(self):
        chunks_dict = {}
        address = self.input_address
        pre_df = pd.read_csv(address)
        df = pre_df.iloc[15:, [1, 3, 5]].values.astype(float)
        df = df[:, 0]
        for i in range(self.start, self.end_point, self.window_size):
            chunks_dict[i // self.window_size] = df[i:i + self.window_size]
        self.chunks_dict = chunks_dict
        os.makedirs(self.output_address, exist_ok=True)

    # def Saveon(self):
    #     for key, chunk in self.chunks_dict.items():
    #         # Generate the recurrence plot (distance matrix)
    #         matrix = self.recurrence_plot_magnitude(chunk)
    #
    #         # Convert the matrix to a PyTorch tensor
    #         tensor = torch.tensor(matrix, dtype=torch.float32)
    #
    #         # Save the tensor to a .pt file
    #         filename_tensor = f'matrix_{key}.pt'
    #         full_path_tensor = os.path.join(self.output_address, filename_tensor)
    #         torch.save(tensor, full_path_tensor)
    #
    #         # Optional: Print a message or log the saved file
    #         print(f"Saved PyTorch tensor: {full_path_tensor}")

    # def Saveon(self):
    #     for key, chunk in self.chunks_dict.items():
    #         # Generate the recurrence plot (distance matrix)
    #         matrix = self.recurrence_plot_magnitude(chunk)
    #
    #         # Convert the matrix to a PyTorch tensor
    #         tensor = torch.tensor(matrix, dtype=torch.float32)
    #
    #         # Use iteration in the filename to make it unique
    #         filename_tensor = f'matrix_iter{key + self.iteration}.pt'
    #         full_path_tensor = os.path.join(self.output_address, filename_tensor)
    #         torch.save(tensor, full_path_tensor)

    def Saveon(self):
        os.makedirs(self.output_address, exist_ok=True)  # Ensure output directory exists

        for key, chunk in self.chunks_dict.items():
            # Generate the recurrence plot (distance matrix)
            matrix = self.recurrence_plot_magnitude(chunk)

            # Convert the matrix to a PyTorch tensor
            tensor = torch.tensor(matrix, dtype=torch.float32)

            # Construct filename with iteration and input file name for clarity
            base_filename = os.path.basename(self.input_address).replace('.csv', '')
            filename_tensor = f'{base_filename}_iter{key + self.iteration}.pt'
            full_path_tensor = os.path.join(self.output_address, filename_tensor)

            # Save the tensor and handle errors
            try:
                torch.save(tensor, full_path_tensor)
                print(f"Saved PyTorch tensor: {full_path_tensor}, Tensor shape: {tensor.shape}")
            except Exception as e:
                print(f"Error saving tensor for chunk {key}: {e}")

# %%
directory_out = r"F:\TheLis\1"
directory_in = r"F:\Thesis\Data Set\Machin_Train_URF\Machin_Train_URF\0\1420"
limit, count = 8, 0
iteration = 0

for filename in sorted(os.listdir(directory_in)):
    if filename.endswith(".CSV") or filename.endswith(".csv"):  # Ensure only CSV files are processed
        if count == limit:
            break
        input_file_path = os.path.join(directory_in, filename)  # Create full path for each file
        RecurrencePlot_v2(input_file_path, directory_out, iteration=iteration)

        count += 1
        iteration = count * 156
        print(input_file_path)
# Out:
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter0.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter1.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter2.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter3.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter4.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter5.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter6.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter7.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter8.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter9.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter10.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_iter11.pt, Tensor shape: torch.Size([160, 160])
# Saved PyTorch tensor: F:\TheLis\1\ALL0001.CSV_i