# %% [markdown]
# # RP Data Set Creator (Numpy ver)
#
# This file create dataset based on Csv file we gave to it,
# out put income is some torch.tensor file's based on RP (Recurrence Plot) technique

# %% [markdown]
# ## Libraries

# %%
import os
import torch
import numpy as np
import pandas as pd

# %% [markdown]
# ## RP technique

# %%
class RecurrencePlot:
    def __init__(self, input_address, output_address, iteration=0, window_size=160, start=0, end_point=24960):
        self.input_address = input_address
        self.output_address = output_address
        self.window_size = window_size
        self.start = start
        self.end_point = end_point
        self.chunks_dict = {}
        self.iteration = iteration
        self.load_data()
        self.Saveon()

    def recurrence_plot_magnitude(self, A):
        N = len(A)
        distance_matrix = np.zeros((N, N))
        for i in range(N):
            for j in range(N):
                distance_matrix[i, j] = np.abs(A[i] - A[j])
        return distance_matrix

    def load_data(self):
        chunks_dict = {}
        address = self.input_address
        pre_df = pd.read_csv(address)
        df = pre_df.iloc[15:, [1, 3, 5]].values.astype(float)
        df = df[:, 0]
        for i in range(self.start, self.end_point, self.window_size):
            chunks_dict[i // self.window_size] = df[i:i + self.window_size]
        self.chunks_dict = chunks_dict
        os.makedirs(self.output_address, exist_ok=True)

    def Saveon(self):
        for key, chunk in self.chunks_dict.items():
            matrix = self.recurrence_plot_magnitude(chunk)

            # Convert to a NumPy array
            np_array = np.array(matrix, dtype=np.float32)

            base_filename = os.path.basename(self.input_address).replace('.csv', '')
            filename_array = f'{base_filename}_iter{key + self.iteration}.npy'
            full_path_array = os.path.join(self.output_address, filename_array)
            try:
                # Save as a .npy file
                np.save(full_path_array, np_array)
                print(f"Saved NumPy array: {full_path_array}, Array shape: {np_array.shape}")
            except Exception as e:
                print(f"Error saving array for chunk {key}: {e}")

# %% [markdown]
# ## Creator

# %%
directory_out = r"G:\Thesis_Numpy_data_set\1000\4_class\3"
directory_in = r"G:\Thesis\Data Set\Machin_Train_URF\Machin_Train_URF\40%\1420"
limit, count = 7, 0
iteration = 0

for filename in sorted(os.listdir(directory_in)):
    if filename.endswith(".CSV") or filename.endswith(".csv"):  # Ensure only CSV files are processed
        if count == limit:
            break
        input_file_path = os.path.join(directory_in, filename)  # Create full path for each file
        RecurrencePlot(input_file_path, directory_out, iteration=iteration)

        count += 1
        iteration = count * 156  # for 160by160
        # iteration = count * 78  # for 320by320
        print(input_file_path)
# Out:
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter0.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter1.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter2.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter3.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter4.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter5.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter6.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter7.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter8.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter9.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter10.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter11.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter12.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter13.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter14.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter15.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter16.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter17.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter18.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter19.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter20.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter21.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter22.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter23.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter24.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter25.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter26.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter27.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter28.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter29.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter30.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter31.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter32.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter33.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter34.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter35.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter36.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter37.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter38.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter39.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter40.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter41.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter42.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter43.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter44.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter45.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter46.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter47.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter48.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter49.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter50.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter51.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter52.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter53.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter54.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter55.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter56.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter57.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter58.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter59.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter60.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter61.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter62.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter63.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter64.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter65.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter66.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter67.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter68.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter69.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter70.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter71.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter72.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter73.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter74.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter75.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter76.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter77.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter78.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter79.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter80.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter81.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter82.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter83.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter84.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter85.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter86.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter87.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter88.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter89.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter90.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter91.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter92.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter93.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter94.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter95.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter96.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter97.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter98.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter99.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter100.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter101.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter102.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter103.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter104.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter105.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter106.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter107.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter108.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter109.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter110.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter111.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter112.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter113.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter114.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter115.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter116.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter117.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter118.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter119.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter120.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter121.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter122.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter123.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter124.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter125.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter126.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter127.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter128.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter129.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter130.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter131.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter132.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter133.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter134.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter135.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter136.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter137.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter138.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter139.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter140.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter141.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter142.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter143.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter144.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter145.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter146.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter147.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter148.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter149.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter150.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter151.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter152.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter153.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter154.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0001.CSV_iter155.npy, Array shape: (160, 160)
# G:\Thesis\Data Set\Machin_Train_URF\Machin_Train_URF\40%\1420\ALL0001.CSV
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter156.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter157.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter158.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter159.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter160.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter161.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter162.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter163.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter164.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter165.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter166.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter167.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter168.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter169.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter170.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_iter171.npy, Array shape: (160, 160)
# Saved NumPy array: G:\Thesis_Numpy_data_set\1000\4_class\3\ALL0002.CSV_i